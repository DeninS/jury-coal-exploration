# %% [markdown]
# # Data cleaning
# by: Denin Sahovic
# Cleaned up the data - removed 0 production data

# %%
output_file = '../data/cleaned_coalpublic2015.csv'
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("../data/coalpublic2015.xls", header=2,index_col='MSHA ID')

# %%
# Mistake, renaming Indepedent
df['Company Type'].unique()
# Out:
# array(['Indepedent Producer Operator', 'Operating Subsidiary', 'Contractor'], dtype=object)

# %%
df['Company Type'].replace(to_replace='Indepedent Producer Operator',
                           value='Independent Producer Operator',
                           inplace=True)

# %%
# changing spaces to _
df.rename(columns=lambda x: x.replace(" ", "_"), inplace=True)

# %%
# We are removing data here !
# Coal mines without ANY production are removed
df = df[df['Production_(short_tons)'] > 0]

# %%
len(df)
# Out:
# 853

# %%
df['log_production'] = np.log(df['Production_(short_tons)'])

# %%
df.to_csv(output_file)
